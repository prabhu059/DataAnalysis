# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/DataSet/marks dataset1.csv')
df
# Out:
#     Hours   avg
# 0     2.5    22
# 1     5.1    72
# 2     3.2    25
# 3     8.5    77
# 4     3.5    31
# 5     1.5    19
# 6     9.2    89
# 7     5.5    59
# 8     8.3    83
# 9     2.7    22
# 10    7.7    86
# 11    5.9    62
# 12    4.5    43
# 13    3.3    41
# 14    1.1    18
# 15    8.9    96
# 16    2.5    32
# 17    1.9    24
# 18    6.1    68
# 19    7.4    68
# 20    2.7    31
# 21    4.8    54
# 22    3.8    35
# 23    6.9    74
# 24    7.8    82

# %%
df.head(5)
# Out:
#    Hours   avg
# 0    2.5    22
# 1    5.1    72
# 2    3.2    25
# 3    8.5    77
# 4    3.5    31

# %%
df.isna().sum()
# Out:
# Hours    0
#  avg     0
# dtype: int64

# %%
df.shape
# Out:
# (25, 2)

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values
print(x)
print(y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
# [22 72 25 77 31 19 89 59 83 22 86 62 43 41 18 96 32 24 68 68 31 54 35 74
#  82]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
print(y_train)
regressor.fit(x_train,y_train)
# Out:
# [35 24 82 74 18 72 86 41 83 89 68 31 22 59 31 77 22 54 96 43]
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='black')
plt.plot(x_train,regressor.predict(x_train),color='yellow')
plt.title("students marks")
plt.xlabel("hours")
plt.xlabel("average")
plt.show()

# %%
plt.scatter(x_test,y_test,color='black')
plt.plot(x_train,regressor.predict(x_train),color='Red')
plt.title("students marks")
plt.xlabel("hours")
plt.xlabel("average")
plt.show()
