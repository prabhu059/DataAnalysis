# %%
import numpy as np
#generate a large volume of random data(eg. 1 millon data points)
volume_data=np.random.rand(1000000)
print("volume of data:",len(volume_data))
# Out:
# volume of data: 1000000

# %%
import time
#simulate streaming data every second for 10 seconds
for i in range(10):
  velocity_data=np.random.rand( )#generate random data
  print("velocity data point:",velocity_data)
  time.sleep(2)#wait for 1 second to simulate real-time data stream
# Out:
# velocity data point: 0.8758429342376598
# velocity data point: 0.9069778818018885
# velocity data point: 0.0363631709121609
# velocity data point: 0.9473991915472703
# velocity data point: 0.8377312904053664
# velocity data point: 0.05069992645462118
# velocity data point: 0.015524422017821449
# velocity data point: 0.5254266958995222
# velocity data point: 0.08589264102223582
# velocity data point: 0.8679167167572157

# %%
#structured data
structured_data={'id':1,'name':'John','age':30}
print(structured_data)
#semi-structured data(JSON)
semi_structured_data={'person':{'name':'Alice','age':25,'city':'New York'}}
#unstructured data(text)
unstructured_data="This is a sample text document.It can contain any information in free form"
# Out:
# {'id': 1, 'name': 'John', 'age': 30}

# %%
import random
#generate some random data with noise
veracity_data=[random.choice([1,2,3,None])for _ in range(20)]
print("veracity data:",veracity_data)
# Out:
# veracity data: [None, 2, None, 1, None, 2, None, 3, None, 2, 2, None, 1, None, 2, None, None, 3, 1, 3]

# %%
# !pip install reportlab
# Out:
# Collecting reportlab
#   Downloading reportlab-4.1.0-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (9.4.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab) (5.2.0)
# Installing collected packages: reportlab
# Successfully installed reportlab-4.1.0
